# %% [markdown]
# # Cleaning and exploring data about Star Wars collected by FiveThirtyEight

# %% [markdown]
# # 1. lets read the data.

# %%
#the data contains some values that can not be read by the default coding settings
import pandas as pd
import numpy as np
star_wars = pd.read_csv("star_wars.csv", encoding="ISO-8859-1")

# %% [markdown]
# # 2. Explore the data

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
#Review the columns names
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %% [markdown]
# # 3. Filter the data to include only the data with the RespondentID as a not Null

# %%
star_wars_updated = star_wars[star_wars['RespondentID'].notnull()]

# %%
#checking the data after the clean up
star_wars_updated.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %% [markdown]
# # 4. Inspect the columns
# - 'Have you seen any of the 6 films in the Star Wars franchise?'
# - 'Do you consider yourself to be a fan of the Star Wars film franchise?'

# %%
star_wars_updated['Have you seen any of the 6 films in the Star Wars franchise?'].value_counts()
# Out:
# Yes    936
# No     250
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
star_wars_updated['Do you consider yourself to be a fan of the Star Wars film franchise?'].value_counts()
# Out:
# Yes    552
# No     284
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: int64

# %% [markdown]
# ## Convert the YES and NO into bolean for both columns

# %%
#create a dictionary to use to map the bolean
yes_no_dic = {'Yes': True, 'No':False}

# %%
#Convert them
star_wars_updated['Do you consider yourself to be a fan of the Star Wars film franchise?'] = star_wars_updated['Do you consider yourself to be a fan of the Star Wars film franchise?'].map(yes_no_dic)
star_wars_updated['Have you seen any of the 6 films in the Star Wars franchise?'] = star_wars_updated['Have you seen any of the 6 films in the Star Wars franchise?'].map(yes_no_dic)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
star_wars_updated['Do you consider yourself to be a fan of the Star Wars film franchise?'].value_counts(dropna =False)
# Out:
# True     552
# NaN      350
# False    284
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: int64

# %%
star_wars_updated['Have you seen any of the 6 films in the Star Wars franchise?'].value_counts(dropna = False)
# Out:
# True     936
# False    250
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %% [markdown]
# # 5. Convert the six columns that are movie titles respondent has seen into a boolean values.
# ### Columns to change are the following
#
# - Which of the following Star Wars films have you seen? Please select all that apply. - Whether or not the respondent saw Star Wars: Episode I The Phantom Menace.
# - Unnamed: 4 - Whether or not the respondent saw Star Wars: Episode II Attack of the Clones.
# - Unnamed: 5 - Whether or not the respondent saw Star Wars: Episode III Revenge of the Sith.
# - Unnamed: 6 - Whether or not the respondent saw Star Wars: Episode IV A New Hope.
# - Unnamed: 7 - Whether or not the respondent saw Star Wars: Episode V The Empire Strikes Back.
# - Unnamed: 8 - Whether or not the respondent saw Star Wars: Episode VI Return of the Jedi.

# %%
#create maping dictionary
movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}

for col in star_wars_updated.columns[3:9]:
    star_wars_updated[col] = star_wars_updated[col].map(movie_mapping)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
star_wars_updated = star_wars_updated.rename(columns={'Which of the following Star Wars films have you seen? Please select all that apply.':'seen_1',
                                                      'Unnamed: 4':'seen_2',
                                                      'Unnamed: 5':'seen_3',
                                                      'Unnamed: 6':'seen_4',
                                                      'Unnamed: 7':'seen_5',
                                                      'Unnamed: 8':'seen_6'})

# %%
star_wars_updated.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 1    True    True    True    True    True    True
# 2   False   False   False   False   False   False
# 3    True    True    True   False   False   False
# ...

# %% [markdown]
# # 6. Convert the data type for the columns

# %%
star_wars_updated[star_wars_updated.columns[9:15]] = star_wars_updated[star_wars_updated.columns[9:15]].astype(float)

# %%
star_wars.columns[9:15]
# Out:
# Index(['Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
star_wars_updated = star_wars_updated.rename(columns = {'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.':'ranking_1','Unnamed: 10':'ranking_2','Unnamed: 11':'ranking_3','Unnamed: 12':'ranking_4','Unnamed: 13':'ranking_5','Unnamed: 14':'ranking_6'})

# %%
star_wars_updated.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  ranking_1  \
# 1    True    True    True    True    True    True        3.0
# 2   False   False   False   False   False   False        NaN
# ...

# %%
star_wars_updated[star_wars_updated.columns[9:15]].mean()
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
plt.bar(range(6),star_wars_updated[star_wars_updated.columns[9:15]].mean())
# Out:
# <Container object of 6 artists>

# %%
plt.bar(range(6), star_wars_updated[star_wars_updated.columns[3:9]].sum())
# Out:
# <Container object of 6 artists>

# %% [markdown]
# # Split the data frame into two

# %%
males = star_wars_updated[star_wars_updated['Gender'] == 'Male']
females =star_wars_updated[star_wars_updated['Gender'] == 'Female']

# %%
females.head()
# Out:
#      RespondentID  \
# 112  3.291440e+09
# 113  3.291439e+09
# 115  3.291436e+09
# 117  3.291434e+09
# 118  3.291432e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 112                                               True
# 113                                               True
# 115                                               True
# 117                                               True
# 118                                               True
#
#     Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 112                                               True
# 113                                              False
# 115                                              False
# 117                                              False
# 118                                               True
#
#      seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  ranking_1  \
# 112    True    True   False   False    True    True        1.0
# ...

# %%
plt.bar(range(6),females[females.columns[9:15]].mean())
# Out:
# <Container object of 6 artists>

# %%
plt.bar(range(6),females[females.columns[3:9]].mean())
# Out:
# <Container object of 6 artists>
